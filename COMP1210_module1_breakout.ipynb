# %%
# !git clone https://github.com/SIT-COMP-1210/Module1-Breakout-meron-source.git
# Out:
# fatal: destination path 'Module1-Breakout-meron-source' already exists and is not an empty directory.

# %% [markdown]
# **Instructions**
#
#
# *   Replace "{YourGitHubUser}" with your GitHub username
# *   Run the cell above to clone this .ipynb file to your git repository
#
#
# *   Once you are done completing the assignment below, click on "File" above, from the dropdown select "Save a copy in GitHub"
# *   Edit the commit message to reflect your latest change (e.g "Submitting Breakout Session Assignment")
#
#
# *   Commit your change
#
#
# *   Lastly, go to GitHub Classroom repository to confirm your file submission

# %% [markdown]
# **Practice Problems**

# %% [markdown]
# 1) What is wrong with this code?
#
#
# *   print("Hello World)
#
# * ANS: No double quote at the end, should be
# * print("Hello World")

# %% [markdown]
# 2. Print all the values below
#
# *   Hello Word
# *   3
# *  2+2

# %%
print("Hello World")
print(3)
print(2+2)
# Out:
# Hello World
# 3
# 4

# %% [markdown]
# 3. Write a code that prints:
#
#
# *   Hello
#
#       Hello
#
#       Hello
#
#       * ANS: print(Hello)
#       * print(Hello)
#       * print(Hello)

# %% [markdown]
# 4. Then combine it to 1 line:
#
#
# *   HelloHelloHello
# * ANS: word=""
# * for i in range(3):
#   * +=word
#  * print(word)

# %% [markdown]
# 5. What will be printed when you run:
#
#
#
#   *   print("2" + "2") ANS: 22
#   *   print(2 + 2)     ANS: 4
#
#   *   print("A")    ANS:A
#   *   print("B")   ANS: B
#
#
#   *   print("A" + "B")  ANS: AB
